# %%
import pandas as pd
import numpy as np

df = pd.read_csv("vaccination-coverage-byVaccineType (3).csv")
df
# Out:
#       pruid                    prename                  prfname    week_end  \
# 0         1                     Canada                   Canada  2020-12-19
# 1         1                     Canada                   Canada  2020-12-19
# 2         1                     Canada                   Canada  2020-12-19
# 3        10  Newfoundland and Labrador  Terre-Neuve-et-Labrador  2020-12-19
# 4        10  Newfoundland and Labrador  Terre-Neuve-et-Labrador  2020-12-19
# ...     ...                        ...                      ...         ...
# 4046     62                    Nunavut                  Nunavut  2021-10-23
# 4047     62                    Nunavut                  Nunavut  2021-10-23
# 4048     62                    Nunavut                  Nunavut  2021-10-23
# 4049     62                    Nunavut                  Nunavut  2021-10-23
# 4050     62                    Nunavut                  Nunavut  2021-10-23
#
# ...
